# %%
import pandas as pd

# %%
df = pd.read_csv("Salaries.csv")
df.set_index("Id")
# Out:
#                 EmployeeName                                        JobTitle  \
# Id
# AA            NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# AB              GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# AC            ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# AD         CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# AE           PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ..                       ...                                             ...
# ZV              CHERYL ADAMS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZW            LOUISE SIMPSON               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZX               BLAKE LOEBS               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZY  ELIZABETH AGUILAR-TARCHI               HEAD ATTORNEY, CIVIL AND CRIMINAL
# ZZ                 JULIAN NG                SERGEANT III (POLICE DEPARTMENT)
#
# ...

# %%
df.describe(include="all")
# Out:
#          Id       EmployeeName     JobTitle        BasePay    OvertimePay  \
# count   675                676          676     676.000000     676.000000
# unique  675                673           93            NaN            NaN
# top      AA  WILLIAM MCFARLAND  FIREFIGHTER            NaN            NaN
# freq      1                  2           74            NaN            NaN
# mean    NaN                NaN          NaN  149900.019867   30577.231657
# std     NaN                NaN          NaN   41837.736210   35124.001536
# min     NaN                NaN          NaN   25400.000000       0.000000
# 25%     NaN                NaN          NaN  117268.875000       0.000000
# 50%     NaN                NaN          NaN  144042.160000   16664.630000
# 75%     NaN                NaN          NaN  184727.132500   57995.962500
# max     NaN                NaN          NaN  294580.020000  245131.880000
#
#              OtherPay  Benefits       TotalPay  TotalPayBenefits    Year  \
# ...

# %%
def find_police(x):
    return "POLICE" in x

df["isPolice"] = df["JobTitle"].apply(find_police)
df["isPolice"].sum()
# Out:
# 139

# %%
def find_fire(x):
    return "FIRE" in x

df["isFire"] = df["JobTitle"].apply(find_fire)
df["isFire"].sum()
# Out:
# 238

# %%
ratio_fire_police = (df["isFire"].sum()) / (df["isPolice"].sum())
print(ratio_fire_police)
# Out:
# 1.7122302158273381

# %%
police_df = df[df['JobTitle'].str.contains("POLICE")]
police_df
# Out:
#      Id       EmployeeName                            JobTitle    BasePay  \
# 1    AB       GARY JIMENEZ     CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2    AC     ALBERT PARDINI     CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11   AL   PATRICIA JACKSON     CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 15   AP    RICHARD CORRIEA  COMMANDER III, (POLICE DEPARTMENT)  198778.01
# 25   AZ       GREGORY SUHR                     CHIEF OF POLICE  256470.41
# ..   ..                ...                                 ...        ...
# 647  YX         STEWART NG                  POLICE OFFICER III  112421.44
# 649  YZ       VICTOR TSANG  LIEUTENANT III (POLICE DEPARTMENT)  149023.98
# 658  ZI  LAWRENCE MCDEVITT    SERGEANT III (POLICE DEPARTMENT)  130505.19
# 663  ZN          HENRY YEE    SERGEANT III (POLICE DEPARTMENT)  130457.93
# 675  ZZ          JULIAN NG    SERGEANT III (POLICE DEPARTMENT)  130457.76
#
#      OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
fire_df = df[df['JobTitle'].str.contains("FIRE")]
fire_df
# Out:
#      Id        EmployeeName  \
# 4    AE     PATRICK GARDNER
# 6    AG           ALSON LEE
# 8    AI      MICHAEL MORRIS
# 9    AJ  JOANNE HAYES-WHITE
# 10   AK       ARTHUR KENNEY
# ..   ..                 ...
# 648  YY        ROHAN KNIGHT
# 650  ZA    PATRICK GRIMESEY
# 654  ZE      DONALD PEOPLES
# 655  ZF       JOHN DARMANIN
# 657  ZH          EDWARD MOY
#
#                                               JobTitle    BasePay  \
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 6                   BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                   BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9               CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10    ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ..                                                 ...        ...
# 648                                        FIREFIGHTER  105934.67
# 650                                        FIREFIGHTER  105934.65
# ...

# %%
police_df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay  Benefits       TotalPay  \
# count     139.000000     139.000000     139.000000       0.0     139.000000
# mean   145121.387482   22760.519640   36203.837554       NaN  204085.744676
# std     39831.546940   27746.990973   32582.371464       NaN   38033.749665
# min     51437.990000       0.000000     819.030000       NaN  180312.670000
# 25%    123192.130000    2573.500000   10900.045000       NaN  185925.070000
# 50%    130481.550000   17715.270000   25444.500000       NaN  193846.110000
# 75%    185369.685000   35564.500000   57426.715000       NaN  205164.760000
# max    261717.600000  245131.880000  137811.380000       NaN  538909.280000
#
#        TotalPayBenefits    Year  Notes  Status
# count        139.000000   139.0    0.0     0.0
# mean      204085.744676  2011.0    NaN     NaN
# std        38033.749665     0.0    NaN     NaN
# min       180312.670000  2011.0    NaN     NaN
# ...

# %%
fire_df["BasePay"].mean()
# Out:
# 128547.8562605042

# %%
fire_df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay  Benefits       TotalPay  \
# count     238.000000     238.000000     238.000000       0.0     238.000000
# mean   128547.856261   51675.418487   25954.411723       NaN  206177.686471
# std     28678.933646   26229.274992   24818.694832       NaN   26613.115222
# min     25400.000000       0.000000    6407.340000       NaN  180560.700000
# 25%    105934.670000   33604.925000   16054.210000       NaN  187615.632500
# 50%    123105.000000   57601.975000   17990.600000       NaN  197729.430000
# 75%    140546.880000   70631.190000   25550.195000       NaN  215255.232500
# max    285262.000000  111729.650000  182234.590000       NaN  326373.190000
#
#        TotalPayBenefits    Year  Notes  Status
# count        238.000000   238.0    0.0     0.0
# mean      206177.686471  2011.0    NaN     NaN
# std        26613.115222     0.0    NaN     NaN
# min       180560.700000  2011.0    NaN     NaN
# ...
